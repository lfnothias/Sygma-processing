# %% [markdown]
# # SyGMA processing for metabolites
#
# Info: Jupyter notebook made by LF and Pryia on April 2018
#
# Description: Process a list of structures (SMILES) and generate Phase I and II metabolites

# %%
import pandas as pd
import numpy as np
import sygma
from rdkit import Chem

# %%
#Open dataframes
df = pd.read_csv("Saliva_InChI.txt",  sep='\t', header=0, encoding='utf-8')
df2 = pd.read_csv("drugbank_approved_structure_links.csv",  sep=',', header=0, encoding='latin-1')
df3 = pd.read_csv("drugbank_illicit_structure_links.csv",  sep=',', header=0, encoding='latin-1')
df4 = pd.read_csv("drugbank_nutraceutical_structure_links.csv",  sep=',', header=0, encoding='latin-1')
df5 = pd.read_csv("FOODB_compounds_3.txt",  sep='\t', header=0, encoding='utf-8')
df6 = pd.read_csv("Exposome_explorer_biomarkers.csv",  sep=',', header=0)
df7 = pd.read_csv("toxins_edited_v2.txt",  sep='\t', header=0, encoding='latin-1')
df8 = pd.read_csv("PTID_Pesticide_3D-Plant2Cells_compound.txt",  sep='\t', header=0, encoding='latin-1')
df6.head(5)
# Out:
#    ID         Name Synonyms     Level Description CAS Number  PubChem ID  \
# 0   1  Polyphenols      NaN  Combined         NaN        NaN         NaN
# 1   5  Isoflavones      NaN  Combined         NaN        NaN         NaN
# 2   3    Genistein      NaN    Single         NaN   446-72-0   5280961.0
# 3   4     Daidzein      NaN    Single         NaN   486-66-8   5281708.0
# 4  10        Equol      NaN    Single         NaN   531-95-3     91469.0
#
#    ChEBI ID   FooDB ID    HMDB ID                                    SMILES  \
# 0       NaN        NaN        NaN                                       NaN
# 1       NaN        NaN        NaN                                       NaN
# 2   28088.0  FDB011828  HMDB03217  OC1=CC=C(C=C1)C1=COC2=CC(O)=CC(O)=C2C1=O
# 3   28197.0  FDB002608  HMDB03312   OC1=CC=C(C=C1)C1=COC2=C(C=CC(O)=C2)C1=O
# 4   34741.0  FDB021824  HMDB02209  OC1=CC=C(C=C1)[C@H]1COC2=C(C1)C=CC(O)=C2
#
#     Formula                                              InChI  \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2  C15H10O5  InChI=1S/C15H10O5/c16-9-3-1-8(2-4-9)11-7-20-13...
# 3  C15H10O4  InChI=1S/C15H10O4/c16-10-3-1-9(2-4-10)13-8-19-...
# 4  C15H14O3  InChI=1S/C15H14O3/c16-13-4-1-10(2-5-13)12-7-11...
#
#                       InChIKey  Average mass  Mono. mass
# 0                          NaN           NaN         NaN
# 1                          NaN           NaN         NaN
# 2  TZBJGXHYKVUXJN-UHFFFAOYSA-N      270.2400  270.052823
# 3  ZQSIJRDFPHDXIC-UHFFFAOYSA-N      254.2410  254.057909
# 4  ADFCQWZHKCXPAJ-GFCCVEGCSA-N      242.2699  242.094294

# %%
#Keep just a column per dataset
df = df[['SMILES']]
df2 = df2[['SMILES']]
df3 = df3[['SMILES']]
df4 = df4[['SMILES']]
df5 = df5[['SMILES']]
df6 = df6[['SMILES']]
df7 = df7[['SMILES']]
df8 = df8[['SMILES']]

# %%
#Concatenate tables
frames = [df, df2, df3, df4, df5, df6, df7, df8]
Table = pd.concat(frames)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-b711dca3c4e8> in <module>()
#       2
#       3 frames = [df2a, df3a, df4a, df5a, df6a, df7a, df8a]
# ----> 4 Table = pd.append(frames)
#       5 Table['ID'] = df2a['DrugBank ID'] + '_' + df3a['DrugBank ID'] + '_' + df4a['DrugBank ID'] + '_' + df6a['HMDB ID'] + '_'+ df7a['T3DB ID'] +'_' + df8a['PTID_num']
#
# AttributeError: module 'pandas' has no attribute 'append'

# %%
Table.head(25)
# Out:
#    DrugBank ID HMDB ID PTID_num  \
# 0      DB00006     NaN      NaN
# 1      DB00014     NaN      NaN
# 2      DB00027     NaN      NaN
# 3      DB00035     NaN      NaN
# 4      DB00050     NaN      NaN
# 5      DB00067     NaN      NaN
# 6      DB00080     NaN      NaN
# 7      DB00091     NaN      NaN
# 8      DB00093     NaN      NaN
# 9      DB00104     NaN      NaN
# 10     DB00106     NaN      NaN
# 11     DB00114     NaN      NaN
# 12     DB00115     NaN      NaN
# 13     DB00117     NaN      NaN
# 14     DB00118     NaN      NaN
# 15     DB00119     NaN      NaN
# 16     DB00120     NaN      NaN
# 17     DB00121     NaN      NaN
# 18     DB00122     NaN      NaN
# 19     DB00123     NaN      NaN
# 20     DB00125     NaN      NaN
# 21     DB00126     NaN      NaN
# 22     DB00127     NaN      NaN
# 23     DB00128     NaN      NaN
# 24     DB00129     NaN      NaN
#
#                                                SMILES T3DB ID  \
# 0   CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...     NaN
# 1   CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...     NaN
# 2   CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...     NaN
# 3   NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...     NaN
# 4   CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...     NaN
# 5                                                 NaN     NaN
# 6   CCCCCCCCCC(=O)N[C@@H](CC1=CNC2=C1C=CC=C2)C(=O)...     NaN
# 7   CC[C@@H]1NC(=O)[C@H]([C@H](O)[C@H](C)C\C=C\C)N...     NaN
# 8   NCCCC[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H]1CSSC[...     NaN
# 9   [H][C@]1(NC(=O)[C@H](CCCCN)NC(=O)[C@@H](CC2=CN...     NaN
# 10  CC(C)C[C@H](NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...     NaN
# 11                    CC1=NC=C(COP(O)(O)=O)C(C=O)=C1O     NaN
# 12  [C@H]1([C@@H]2[C@H]([C@@H](N3C4=CC(=C(C)C=C4[N...     NaN
# 13                          N[C@@H](CC1=CN=CN1)C(O)=O     NaN
# 14  [H][C@](N)(CC[S+](C)C[C@@]1([H])O[C@@]([H])(N2...     NaN
# 15                                       CC(=O)C(O)=O     NaN
# 16                        N[C@@H](CC1=CC=CC=C1)C(O)=O     NaN
# 17   [H][C@]12CS[C@@H](CCCCC(O)=O)[C@@]1([H])NC(=O)N2     NaN
# 18                                     C[N+](C)(C)CCO     NaN
# 19                                NCCCC[C@H](N)C(O)=O     NaN
# 20                          N[C@@H](CCCNC(N)=N)C(O)=O     NaN
# 21               [H][C@@]1(OC(=O)C(O)=C1O)[C@@H](O)CO     NaN
# 22                                     NCCCNCCCCNCCCN     NaN
# 23                             N[C@@H](CC(O)=O)C(O)=O     NaN
# 24                                 NCCC[C@H](N)C(O)=O     NaN
#
#                                                 ID
# 0                                              NaN
# 1                                              NaN
# 2   DB00027_DB00191_DB00116_HMDB03217_T3D0802_1043
# 3   DB00035_DB00230_DB00117_HMDB03312_T3D1641_1452
# 4    DB00050_DB00237_DB00118_HMDB02209_T3D0671_509
# 5    DB00067_DB00241_DB00119_HMDB04629_T3D1450_909
# 6   DB00080_DB00306_DB00120_HMDB05781_T3D3961_1523
# 7   DB00091_DB00318_DB00121_HMDB05760_T3D3652_1000
# 8   DB00093_DB00327_DB00122_HMDB05897_T3D1780_1422
# 9   DB00104_DB00349_DB00123_HMDB05794_T3D4476_1500
# 10     DB00106_DB00371_DB00125_HMDB05801_T3D0806_1
# 11  DB00114_DB00404_DB00126_HMDB02670_T3D4511_1421
# 12  DB00115_DB00470_DB00127_HMDB05782_T3D3913_1399
# 13                                             NaN
# 14                                             NaN
# 15  DB00119_DB00574_DB00130_HMDB03306_T3D0914_1463
# 16  DB00120_DB00611_DB00131_HMDB02655_T3D0939_1146
# 17   DB00121_DB00628_DB00132_HMDB06101_T3D0896_270
# 18                                             NaN
# 19   DB00123_DB00683_DB00134_HMDB05810_T3D0708_834
# 20   DB00125_DB00690_DB00135_HMDB02937_T3D3956_257
# 21  DB00126_DB00801_DB00136_HMDB02124_T3D1004_1082
# 22   DB00127_DB00802_DB00137_HMDB03993_T3D4479_851
# 23  DB00128_DB00813_DB00138_HMDB33844_T3D4772_1363
# 24   DB00129_DB00829_DB00139_HMDB02789_T3D0941_248

# %%
Table.shape
# Out:
# (16966, 5)

# %%
len(Table.SMILES.unique())
# Out:
# 14735

# %%
#Remove empty rows
Table_clean = Table[Table.SMILES.str.contains('nan') == False]

# Remove steoreochemistry from SMILES
Table_clean['SMILES'].replace(regex=True,inplace=True,to_replace=r'@@',value=r'')
Table_clean['SMILES'].replace(regex=True,inplace=True,to_replace=r'@',value=r'')
Table_clean['SMILES'].replace(regex=True,inplace=True,to_replace=r'/',value=r'')
Table_clean['SMILES'].replace(regex=True,inplace=True,to_replace=r'\\',value=r'')

#Filter SMILES and Formula lenght
Table_clean = Table_clean[Table_clean['SMILES'].map(len) > 8]
Table_clean = Table_clean[Table_clean['SMILES'].map(len) < 125]

#Sort by InChI lenght
Table_clean.sort_values('SMILES',inplace=True, ascending=False)
Table_clean.index = Table_clean['SMILES'].str.len()
Table_clean = Table_clean.sort_index(ascending=False).reset_index(drop=True)
Table_clean.shape
# Out:
# /home/labshare/.local/lib/python3.6/site-packages/pandas/core/generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# (12748, 5)

# %%
#Write the file out
Table_clean.to_csv('Combined_DB_DrugDB_FoodDB_Pesticide_Exposome_Sygma_SMILES.tsv', sep = '\t', index = False)

# %%
#Make full list from SMILES column
List_smiles = []
List_smiles = Table_clean['SMILES'].tolist()
List_smiles

#Remove duplicates
List_smiles_unique = []
for item in List_smiles:
    if item not in List_smiles_unique:
        List_smiles_unique.append(item)
        
print(len(List_smiles_unique))
# Out:
# 11288

# %% [markdown]
# ## Running SyGMa
#
# Each step in a scenario lists the ruleset
# and the number of reaction cycles to be applied

# %%
# Define SyGMA scenario. 
scenario = sygma.Scenario([
    [sygma.ruleset['phase1'], 1],
    [sygma.ruleset['phase2'], 1]])

# %%
# Create a list of RDkit object from smiles
list_mol = [Chem.MolFromSmiles(x) for x in List_smiles_unique]
list_mol
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x7f35847c55d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585186da0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85a30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e859e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85b20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85b70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85c10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85c60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85d00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85d50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85da0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85df0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85e40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85e90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35836b12b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e85f80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851940d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851941c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851942b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851943a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851943f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851944e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851945d0>,
#  None,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851946c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851947b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851948a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851948f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194940>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f35851949e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194a30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194a80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194b20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194b70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194c10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194c60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194d00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194d50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194da0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194df0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194e40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194e90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194f30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585194f80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f0d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f940>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6f9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fa30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fa80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fad0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fb20>,
#  None,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fb70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fbc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fc10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fc60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fcb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fd00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fd50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fda0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fdf0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fe40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fe90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6fee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ff30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ff80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73f80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73f30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73e90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73e40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73df0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73da0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73d00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73d50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73c10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73b70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73b20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e739e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e737b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e736c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e735d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e734e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73c60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e733a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73a30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73a80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e738a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e738f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e732b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73940>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e731c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e730d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e733f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e73080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e790d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e791c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e792b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e793a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e793f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e794e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e795d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e796c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e797b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e798a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e798f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79940>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e799e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e79a30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e
,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e2b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e3a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e3f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e4e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e530>,
#  None,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e5d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e6c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e7b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e8a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e8f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e940>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6e9e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ea30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ea80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ead0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6eb20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6eb70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ebc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ec10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ec60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ecb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ed00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ed50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6eda0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6edf0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ee40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ee90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6eee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ef30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e6ef80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e934e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e933f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e930d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e931c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93a30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e933a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e935d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e936c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93a80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e937b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93800>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93940>,
#  None,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e938f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e938a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93850>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93bc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93b20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93b70>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e932b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93ad0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93620>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93c60>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93c10>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93d50>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93670>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93e90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93f80>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93760>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93710>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93f30>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93df0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93da0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93e40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e939e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93d00>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93990>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e93cb0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83030>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83080>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e830d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83170>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e831c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83210>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83260>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e832b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83300>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83350>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e833a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e833f0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83440>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83490>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e834e0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83530>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83580>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e835d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f3585e83620>,
#  ...]

# %%
# Remove None
list_mol_clean = [x for x in list_mol if x!=None]

# %%
print(len(list_mol))
print(len(list_mol_clean))
# Out:
# 11288
# 10110

# %%
df = pd.DataFrame(data=None)
df2 = pd.DataFrame(data=None)
for x in list_mol_clean:
    print(x)
    metabolic_tree = scenario.run(x)
    metabolic_tree.calc_scores()
    metabolites = metabolic_tree.to_smiles()
    df = pd.DataFrame(metabolites[1:],columns=metabolites[0])
    df['parent'] = (metabolites[0][0])
    df.columns.values[0] = 'metabolite'
    df.columns.values[1] = 'score'
    #Keep only top20
    df2 = df2.append(df[:20], ignore_index=True)
# Out:
# <rdkit.Chem.rdchem.Mol object at 0x7f35847c55d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585186da0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85a30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e859e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85ad0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85b20>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85b70>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85bc0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85c10>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85c60>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85cb0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85d00>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85d50>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85da0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85df0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85e40>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85e90>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85ee0>
# <rdkit.Chem.rdchem.Mol object at 0x7f35836b12b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e85f80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194030>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194080>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851940d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194120>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194170>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851941c0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194210>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194260>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851942b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194300>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194350>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851943a0>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851943f0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194440>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194490>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851944e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194530>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194580>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851945d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194620>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194670>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851946c0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194710>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194760>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851947b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194800>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194850>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851948a0>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851948f0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194940>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194990>
# <rdkit.Chem.rdchem.Mol object at 0x7f35851949e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194a30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194a80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194ad0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194b20>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194b70>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194bc0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194c10>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194c60>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194cb0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194d00>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194d50>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194da0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194df0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194e40>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194e90>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194ee0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194f30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585194f80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f030>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f080>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f0d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f120>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f170>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f1c0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f210>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f260>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f2b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f300>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f350>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f3a0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f3f0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f440>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f490>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f4e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f530>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f580>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f5d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f620>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f670>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f6c0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f710>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f760>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f7b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f800>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f850>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f8a0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f8f0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f940>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f990>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6f9e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fa30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fa80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fad0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fb20>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fb70>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fbc0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fc10>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fc60>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fcb0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fd00>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fd50>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fda0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fdf0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fe40>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fe90>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6fee0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6ff30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e6ff80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73f80>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73f30>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73ee0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73e90>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73e40>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73df0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73da0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73d00>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73d50>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73cb0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73c10>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73300>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73b70>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73b20>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73ad0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e739e0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73990>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73850>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73800>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e737b0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73670>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e736c0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73620>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e735d0>
# <rdkit.Chem.rdchem.Mol object at 0x7f3585e73580>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-284-9915e804e55e> in <module>()
#       3 for x in list_mol_clean:
#       4     print(x)
# ----> 5     metabolic_tree = scenario.run(x)
#       6     metabolic_tree.calc_scores()
#       7     metabolites = metabolic_tree.to_smiles()
#
# ~/anaconda3/envs/rdkit/lib/python3.6/site-packages/sygma/scenario.py in run(self, parentmol)
#      43             logger.info('Applying rules: ' + name)
#      44             tree.metabolize_all_nodes(rules, cycles)
# ---> 45         tree.add_coordinates()
#      46         return tree
#      47
#
# ~/anaconda3/envs/rdkit/lib/python3.6/site-packages/sygma/tree.py in add_coordinates(self)
#      71         """
#      72         for node in self.nodes.values():
# ---> 73             node.gen_coords()
#      74
#      75     def calc_scores(self):
#
# ~/anaconda3/envs/rdkit/lib/python3.6/site-packages/sygma/treenode.py in gen_coords(self)
#      56                     n += 1
#      57                     total += rdMolTransforms.GetBondLength(conf, b, e)
# ---> 58             av = total / n
#      59             # compute coordinates for new atoms, keeping known coordinates
#      60             AllChem.Compute2DCoords(self.mol, coordMap=coord_dict, bondLength=av)
#
# ZeroDivisionError: float division by zero

# %%
df2.shape
# Out:
# (2869, 3)

# %%
#Number of unique parent
len(df2.parent.unique())
# Out:
# 142

# %%
df2.head(5)
# Out:
#                                           metabolite  score  \
# 0  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...  0.271
# 1  CCCCCCCC(O)CC(=O)S(=O)CCNC(=O)CCNC(=O)C(O)C(C)...  0.237
# 2    CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)CO  0.203
# 3  Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)O)C(OP(=...  0.203
# 4  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...  0.203
#
#                                               parent
# 0  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...
# 1  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...
# 2  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...
# 3  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...
# 4  CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...

# %%
#Write the file out
df2.to_csv('Combined_DB_DrugDB_FoodDB_Pesticide_Exposome_Sygma_1_1_metabolites.tsv', sep = '\t', index = False)
